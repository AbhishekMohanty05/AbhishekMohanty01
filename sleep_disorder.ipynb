# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhishekMohanty05/AbhishekMohanty01/blob/main/sleep_disorder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/sleep_disorder.csv',encoding='ISO-8859-1')

# %%
df .head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %%
df.shape
# Out:
# (374, 13)

# %%
df.info() #data=df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
df.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# ...

# %%
df['Sleep Disorder'].fillna('None',inplace=True)
print(df['Sleep Disorder'].value_counts())
px.pie(df,names='Sleep Disorder',title='Percentage of each class')
# Out:
# Sleep Disorder
# None           219
# Sleep Apnea     78
# Insomnia        77
# Name: count, dtype: int64
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
print (df['Occupation'].value_counts())
plt.figure(figsize=(10, 8))
sns.countplot(data=df, y='Occupation', hue='Sleep Disorder')
plt.title('Count of Sleep Disorders by Occupation')
plt.xlabel('Count')
plt.ylabel('Occupation')
plt.show()
# Out:
# Occupation
# Nurse                   73
# Doctor                  71
# Engineer                63
# Lawyer                  47
# Teacher                 40
# Accountant              37
# Salesperson             32
# Software Engineer        4
# Scientist                4
# Sales Representative     2
# Manager                  1
# Name: count, dtype: int64

# %%
print (df['BMI Category'].value_counts())
plt.figure(figsize=(10, 8))
sns.countplot(data=df, y='Occupation', hue='Sleep Disorder')
plt.title('Count of Sleep Disorders by Occupation')
plt.xlabel('Count')
plt.ylabel('Occupation')
plt.show()
# Out:
# BMI Category
# Normal           195
# Overweight       148
# Normal Weight     21
# Obese             10
# Name: count, dtype: int64

# %%
average_age_by_occupation=df.groupby('Occupation')['Age'].mean().reset_index()
sns.barplot(x='Age',y='Occupation',data=average_age_by_occupation)
average_age_by_occupation
# Out:
#               Occupation        Age
# 0             Accountant  39.621622
# 1                 Doctor  32.676056
# 2               Engineer  46.587302
# 3                 Lawyer  39.425532
# 4                Manager  45.000000
# 5                  Nurse  51.794521
# 6   Sales Representative  28.000000
# 7            Salesperson  43.531250
# 8              Scientist  33.500000
# 9      Software Engineer  31.250000
# 10               Teacher  41.725000

# %%
average_sleep_by_occupation = df.groupby('Occupation')['Sleep Duration'].mean().reset_index()

# Create the bar plot
plt.figure(figsize=(10, 8))  # Adjust the figure size if needed
sns.barplot(x='Sleep Duration', y='Occupation', data=average_sleep_by_occupation, orient='h')
plt.xlabel('Average Sleep Duration')
plt.ylabel('Occupation')
plt.title('Average Sleep Duration by Occupation')
plt.show()

# %%
print(df['Gender'].value_counts())
print(pd.crosstab(index=df['Sleep Disorder'],columns=df['Gender']))
sns.countplot(data=df,x=df['Gender'],hue='Sleep Disorder')
# Out:
# Gender
# Male      189
# Female    185
# Name: count, dtype: int64
# Gender          Female  Male
# Sleep Disorder
# Insomnia            36    41
# None                82   137
# Sleep Apnea         67    11
# <Axes: xlabel='Gender', ylabel='count'>

# %%
print(df['BMI Category'].value_counts())

# Create a count plot using seaborn
plt.figure(figsize=(10, 8))  # Adjust the figure size if needed
sns.countplot(data=df, y='BMI Category', hue='Sleep Disorder')
plt.xlabel('Count')
plt.ylabel('BMI Category')
plt.title('Count of BMI Category by Sleep Disorder')
plt.show()
# Out:
# BMI Category
# Normal           195
# Overweight       148
# Normal Weight     21
# Obese             10
# Name: count, dtype: int64

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# Plot the count of 'Quality of Sleep' with 'Sleep Disorder' hue on the first subplot (axs[0])
sns.countplot(data=df, x='Quality of Sleep', hue='Sleep Disorder', ax=axs[0])
axs[0].set_xlabel('Quality of Sleep')
axs[0].set_ylabel('Count')
axs[0].set_title('Count of Quality of Sleep by Sleep Disorder')

# Plot the count of 'Stress Level' with 'Sleep Disorder' hue on the second subplot (axs[1])
sns.countplot(data=df, x='Stress Level', hue='Sleep Disorder', ax=axs[1])
axs[1].set_xlabel('Stress Level')
axs[1].set_ylabel('Count')
axs[1].set_title('Count of Stress Level by Sleep Disorder')

# Adjust layout to prevent overlapping labels
plt.tight_layout()

# Show the plots
plt.show()

# %%
plt.figure(figsize=(10, 8))  # Adjust the figure size if needed
sns.scatterplot(data=df, x='Age', y='Sleep Duration', hue='Sleep Disorder')
plt.xlabel('Age')
plt.ylabel('Sleep Duration')
plt.title('Scatter Plot of Age vs. Sleep Duration (Colored by Sleep Disorder)')
plt.legend(title='Sleep Disorder', loc='upper right')  # Add legend with title
plt.show()

# %%
plt.figure(figsize=(10, 8))  # Adjust the figure size if needed
sns.histplot(data=df, x='Age', hue='BMI Category', multiple='stack')
plt.xlabel('Age')
plt.title('Stacked Histogram of Age by BMI Category')
plt.legend(title='BMI Category')  # Add legend with title
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df['Blood Pressure'][:7]
# Out:
# 0    126/83
# 1    125/80
# 2    125/80
# 3    140/90
# 4    140/90
# 5    140/90
# 6    140/90
# Name: Blood Pressure, dtype: object

# %%
df[['Blood_Pressure1','Blood_Pressure2']]=df['Blood Pressure'].str.split('/',expand=True)
df.drop(columns=['Blood Pressure'],inplace=True)

# %%
# Create a figure and axes for subplots
fig, axs = plt.subplots(1, 2, figsize=(12, 6))  # Adjust figsize as needed

# Plot the first histogram on the first subplot (axs[0])
sns.histplot(data=df, x='Blood_Pressure1', hue='Sleep Disorder', multiple="stack", ax=axs[0])

# Plot the second histogram on the second subplot (axs[1])
sns.histplot(data=df, x='Blood_Pressure2', hue='Sleep Disorder', multiple="stack", ax=axs[1])

# Add labels and title to each subplot (optional)
axs[0].set_xlabel('Blood Pressure 1')
axs[0].set_title('Blood Pressure 1 Distribution')

axs[1].set_xlabel('Blood Pressure 2')
axs[1].set_title('Blood Pressure 2 Distribution')

# Add legend to each subplot
axs[0].legend(title='Sleep Disorder')
axs[1].legend(title='Sleep Disorder')

# Adjust layout to avoid overlap of subplots
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
columns_of_interest = ['Age', 'Sleep Duration', 'Quality of Sleep',
                       'Physical Activity Level', 'Stress Level',
                       'Heart Rate', 'Daily Steps',
                       'Blood_Pressure1', 'Blood_Pressure2']

# Calculate the correlation matrix
correlation_matrix = df[columns_of_interest].corr()

# Plotting the heatmap
plt.figure(figsize=(12, 8))  # Adjust the figure size as needed
sns.heatmap(correlation_matrix, annot=True, fmt=".1f", cmap="coolwarm")

# Add title and display the plot
plt.title('Correlation Matrix')
plt.show()

# %%
#SUMMARY
#1.MULTICLASSIFICATION TASK WITH 3 CLASSES
#2.40% OF ENTITIES HAVE SLEEP DISOR

# %%
df.isna().sum()
# Out:
# Person ID                  0
# Gender                     0
# Age                        0
# Occupation                 0
# Sleep Duration             0
# Quality of Sleep           0
# Physical Activity Level    0
# Stress Level               0
# BMI Category               0
# Heart Rate                 0
# Daily Steps                0
# Sleep Disorder             0
# Blood_Pressure1            0
# Blood_Pressure2            0
# dtype: int64

# %%
x=df.drop(columns=['Sleep Disorder','Person ID'])
y=df[['Sleep Disorder']]
from sklearn.model_selection import train_test_split
x_train,x_val,y_train,y_val=train_test_split(x,y,test_size=0.2,random_state=13)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier

def eval_model(y_true,y_predicted):
  cm=confusion_matrix(y_true,y_predicted)
  cm_display=ConfusionMatrixDisplay(confusion_matrix=cm)
  cm_display.plot()
  print('accuracy score',accuracy_score(y_true,y_predicted))

# %%
#DUMMY CLASSIFIER
print('accuracy score for DummyClassifier(baseline)',accuracy_score(y_val,(DummyClassifier().fit(x_train,y_train).predict(x_val))))
# Out:
# accuracy score for DummyClassifier(baseline) 0.5866666666666667

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# %%
x_train['Gender']= label_encoder.fit_transform(x_train['Gender'])
x_train['Occupation']= label_encoder.fit_transform(x_train['Occupation'])
x_train['BMI Category']= label_encoder.fit_transform(x_train['BMI Category'])

# %%
x_val['Gender']= label_encoder.fit_transform(x_val['Gender'])
x_val['Occupation']= label_encoder.fit_transform(x_val['Occupation'])
x_val['BMI Category']= label_encoder.fit_transform(x_val['BMI Category'])

# %%
df.head()
# Out:
#    Person ID  Gender  Age  Occupation  Sleep Duration  Quality of Sleep  \
# 0          1       1   27           9             6.1                 6
# 1          2       1   28           1             6.2                 6
# 2          3       1   28           1             6.2                 6
# 3          4       1   28           6             5.9                 4
# 4          5       1   28           6             5.9                 4
#
#    Physical Activity Level  Stress Level  BMI Category  Heart Rate  \
# 0                       42             6             3          77
# 1                       60             8             0          75
# 2                       60             8             0          75
# 3                       30             8             2          85
# 4                       30             8             2          85
#
#    Daily Steps Sleep Disorder Blood_Pressure1 Blood_Pressure2
# 0         4200           None             126              83
# ...

# %%
DT=DecisionTreeClassifier(criterion='gini',max_depth=5,min_samples_split=3)
DT.fit(x_train,y_train)
y_predicted=DT.predict(x_val)
eval_model(y_val,y_predicted)
# Out:
# accuracy score 0.9333333333333333

# %%
y_train.head()
# Out:
#     Sleep Disorder
# 346    Sleep Apnea
# 101           None
# 196       Insomnia
# 46            None
# 302           None

# %%
x_val.head()
# Out:
#      Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# 18   Female   29      Nurse             6.5                 5
# 172    Male   41     Lawyer             7.7                 8
# 289  Female   50      Nurse             6.1                 6
# 29     Male   30     Doctor             7.9                 7
# 37     Male   31     Doctor             7.6                 7
#
#      Physical Activity Level  Stress Level   BMI Category  Heart Rate  \
# 18                        40             7  Normal Weight          80
# 172                       90             5         Normal          70
# 289                       90             8     Overweight          75
# 29                        75             6         Normal          70
# 37                        75             6         Normal          70
#
#      Daily Steps Blood_Pressure1 Blood_Pressure2
# 18          4000             132              87
# 172         8000             130              85
# ...
